# %%
import csv

with open("../startup_funding.csv", "rt") as csvfile:
    file_data = csv.reader(csvfile, delimiter=",", quotechar='"')
    headers = next(file_data)
    csv_data = [dict(zip(headers, i)) for i in file_data]

# %%
csv_data
# Out:
# [{'permalink': 'lifelock',
#   'company_name': 'LifeLock',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Tempe',
#   'state': 'AZ',
#   'funded_date': '1-May-07',
#   'raised_amount': '6850000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'lifelock',
#   'company_name': 'LifeLock',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Tempe',
#   'state': 'AZ',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'lifelock',
#   'company_name': 'LifeLock',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Tempe',
#   'state': 'AZ',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '25000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'mycityfaces',
#   'company_name': 'MyCityFaces',
#   'number_employees': '7',
#   'category': 'web',
#   'city': 'Scottsdale',
#   'state': 'AZ',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '50000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'flypaper',
#   'company_name': 'Flypaper',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Phoenix',
#   'state': 'AZ',
#   'funded_date': '1-Feb-08',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'infusionsoft',
#   'company_name': 'Infusionsoft',
#   'number_employees': '105',
#   'category': 'software',
#   'city': 'Gilbert',
#   'state': 'AZ',
#   'funded_date': '1-Oct-07',
#   'raised_amount': '9000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'gauto',
#   'company_name': 'gAuto',
#   'number_employees': '4',
#   'category': 'web',
#   'city': 'Scottsdale',
#   'state': 'AZ',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '250000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'chosenlist-com',
#   'company_name': 'ChosenList.com',
#   'number_employees': '5',
#   'category': 'web',
#   'city': 'Scottsdale',
#   'state': 'AZ',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '140000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'chosenlist-com',
#   'company_name': 'ChosenList.com',
#   'number_employees': '5',
#   'category': 'web',
#   'city': 'Scottsdale',
#   'state': 'AZ',
#   'funded_date': '25-Jan-08',
#   'raised_amount': '233750',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'digg',
#   'company_name': 'Digg',
#   'number_employees': '60',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Dec-06',
#   'raised_amount': '8500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'digg',
#   'company_name': 'Digg',
#   'number_employees': '60',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Oct-05',
#   'raised_amount': '2800000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Sep-04',
#   'raised_amount': '500000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-May-05',
#   'raised_amount': '12700000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '27500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Oct-07',
#   'raised_amount': '300000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Mar-08',
#   'raised_amount': '40000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '15-Jan-08',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-May-08',
#   'raised_amount': '100000000',
#   'raised_currency': 'USD',
#   'round': 'debt_round'},
#  {'permalink': 'photobucket',
#   'company_name': 'Photobucket',
#   'number_employees': '60',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-May-06',
#   'raised_amount': '10500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'photobucket',
#   'company_name': 'Photobucket',
#   'number_employees': '60',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Mar-05',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'omnidrive',
#   'company_name': 'Omnidrive',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Dec-06',
#   'raised_amount': '800000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'geni',
#   'company_name': 'Geni',
#   'number_employees': '18',
#   'category': 'web',
#   'city': 'West Hollywood',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'geni',
#   'company_name': 'Geni',
#   'number_employees': '18',
#   'category': 'web',
#   'city': 'West Hollywood',
#   'state': 'CA',
#   'funded_date': '1-Mar-07',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'twitter',
#   'company_name': 'Twitter',
#   'number_employees': '17',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '5400000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'twitter',
#   'company_name': 'Twitter',
#   'number_employees': '17',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-May-08',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'stumbleupon',
#   'company_name': 'StumbleUpon',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Dec-05',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'gizmoz',
#   'company_name': 'Gizmoz',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-May-07',
#   'raised_amount': '6300000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'gizmoz',
#   'company_name': 'Gizmoz',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '16-Mar-08',
#   'raised_amount': '6500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'scribd',
#   'company_name': 'Scribd',
#   'number_employees': '14',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-06',
#   'raised_amount': '12000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'scribd',
#   'company_name': 'Scribd',
#   'number_employees': '14',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '40000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'scribd',
#   'company_name': 'Scribd',
#   'number_employees': '14',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '3710000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'slacker',
#   'company_name': 'Slacker',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '40000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'slacker',
#   'company_name': 'Slacker',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '13500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'lala',
#   'company_name': 'Lala',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-May-07',
#   'raised_amount': '9000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'plaxo',
#   'company_name': 'Plaxo',
#   'number_employees': '50',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Nov-02',
#   'raised_amount': '3800000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'plaxo',
#   'company_name': 'Plaxo',
#   'number_employees': '50',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Jul-03',
#   'raised_amount': '8500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'plaxo',
#   'company_name': 'Plaxo',
#   'number_employees': '50',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Apr-04',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'plaxo',
#   'company_name': 'Plaxo',
#   'number_employees': '50',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Feb-07',
#   'raised_amount': '9000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'powerset',
#   'company_name': 'Powerset',
#   'number_employees': '60',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '12500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'technorati',
#   'company_name': 'Technorati',
#   'number_employees': '25',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-06',
#   'raised_amount': '10520000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'technorati',
#   'company_name': 'Technorati',
#   'number_employees': '25',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Sep-04',
#   'raised_amount': '6500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'technorati',
#   'company_name': 'Technorati',
#   'number_employees': '25',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '13-Jun-08',
#   'raised_amount': '7500000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'technorati',
#   'company_name': 'Technorati',
#   'number_employees': '25',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '10-May-07',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'mahalo',
#   'company_name': 'Mahalo',
#   'number_employees': '40',
#   'category': 'web',
#   'city': 'Santa Monica',
#   'state': 'CA',
#   'funded_date': '1-Jan-06',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'mahalo',
#   'company_name': 'Mahalo',
#   'number_employees': '40',
#   'category': 'web',
#   'city': 'Santa Monica',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '16000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'kyte',
#   'company_name': 'Kyte',
#   'number_employees': '40',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '2250000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'kyte',
#   'company_name': 'Kyte',
#   'number_employees': '40',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Dec-07',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'kyte',
#   'company_name': 'Kyte',
#   'number_employees': '40',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '10-Mar-08',
#   'raised_amount': '6100000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'veoh',
#   'company_name': 'Veoh',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '12500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'veoh',
#   'company_name': 'Veoh',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '1-Aug-07',
#   'raised_amount': '25000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'veoh',
#   'company_name': 'Veoh',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '1-Jul-05',
#   'raised_amount': '2250000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'veoh',
#   'company_name': 'Veoh',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '3-Jun-08',
#   'raised_amount': '30000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'jingle-networks',
#   'company_name': 'Jingle Networks',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '30000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'jingle-networks',
#   'company_name': 'Jingle Networks',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-Dec-05',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'jingle-networks',
#   'company_name': 'Jingle Networks',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '26000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'jingle-networks',
#   'company_name': 'Jingle Networks',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-Oct-05',
#   'raised_amount': '400000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'jingle-networks',
#   'company_name': 'Jingle Networks',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '13000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'ning',
#   'company_name': 'Ning',
#   'number_employees': '41',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '44000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'ning',
#   'company_name': 'Ning',
#   'number_employees': '41',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Apr-08',
#   'raised_amount': '60000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'jotspot',
#   'company_name': 'JotSpot',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Aug-04',
#   'raised_amount': '5200000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'mercora',
#   'company_name': 'Mercora',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Sunnyvale',
#   'state': 'CA',
#   'funded_date': '1-Jan-05',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'wesabe',
#   'company_name': 'Wesabe',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Feb-07',
#   'raised_amount': '700000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'wesabe',
#   'company_name': 'Wesabe',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '4000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'jangl',
#   'company_name': 'Jangl',
#   'number_employees': '22',
#   'category': 'web',
#   'city': 'Pleasanton',
#   'state': 'CA',
#   'funded_date': '1-Jul-06',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'hyphen8',
#   'company_name': 'Hyphen 8',
#   'number_employees': '4',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Oct-07',
#   'raised_amount': '100000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'prosper',
#   'company_name': 'Prosper',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '20000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'prosper',
#   'company_name': 'Prosper',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Apr-05',
#   'raised_amount': '7500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'prosper',
#   'company_name': 'Prosper',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Feb-06',
#   'raised_amount': '12500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'google',
#   'company_name': 'Google',
#   'number_employees': '20000',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Jun-99',
#   'raised_amount': '25000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'jajah',
#   'company_name': 'Jajah',
#   'number_employees': '80',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-May-07',
#   'raised_amount': '20000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'jajah',
#   'company_name': 'Jajah',
#   'number_employees': '80',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Mar-06',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'jajah',
#   'company_name': 'Jajah',
#   'number_employees': '80',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'youtube',
#   'company_name': 'YouTube',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Bruno',
#   'state': 'CA',
#   'funded_date': '1-Nov-05',
#   'raised_amount': '3500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'youtube',
#   'company_name': 'YouTube',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Bruno',
#   'state': 'CA',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'ustream',
#   'company_name': 'Ustream',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Dec-07',
#   'raised_amount': '2000000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'ustream',
#   'company_name': 'Ustream',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '10-Apr-08',
#   'raised_amount': '11100000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'gizmoproject',
#   'company_name': 'GizmoProject',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '1-Feb-06',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'adap-tv',
#   'company_name': 'Adap.tv',
#   'number_employees': '15',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'topix',
#   'company_name': 'Topix',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Nov-06',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'revision3',
#   'company_name': 'Revision3',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Sep-06',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'revision3',
#   'company_name': 'Revision3',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'aggregateknowledge',
#   'company_name': 'Aggregate Knowledge',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '1-Jun-06',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'aggregateknowledge',
#   'company_name': 'Aggregate Knowledge',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '1-Apr-07',
#   'raised_amount': '20000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'sugarinc',
#   'company_name': 'Sugar Inc',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'sugarinc',
#   'company_name': 'Sugar Inc',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'zing',
#   'company_name': 'Zing',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '13000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'criticalmetrics',
#   'company_name': 'CriticalMetrics',
#   'number_employees': '4',
#   'category': 'web',
#   'city': '',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '100000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'spock',
#   'company_name': 'Spock',
#   'number_employees': '30',
#   'category': 'web',
#   'city': 'Redwood City',
#   'state': 'CA',
#   'funded_date': '1-Dec-06',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'wize',
#   'company_name': 'Wize',
#   'number_employees': '',
#   'category': 'web',
#   'city': '',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '4000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'sodahead',
#   'company_name': 'SodaHead',
#   'number_employees': '',
#   'category': 'web',
#   'city': '',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '4250000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'sodahead',
#   'company_name': 'SodaHead',
#   'number_employees': '',
#   'category': 'web',
#   'city': '',
#   'state': 'CA',
#   'funded_date': '25-Jun-08',
#   'raised_amount': '8400000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'casttv',
#   'company_name': 'CastTV',
#   'number_employees': '0',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Apr-07',
#   'raised_amount': '3100000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'buzznet',
#   'company_name': 'BuzzNet',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Hollywood',
#   'state': 'CA',
#   'funded_date': '1-May-07',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'buzznet',
#   'company_name': 'BuzzNet',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Hollywood',
#   'state': 'CA',
#   'funded_date': '7-Apr-08',
#   'raised_amount': '25000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'funny-or-die',
#   'company_name': 'Funny Or Die',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Dec-07',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'sphere',
#   'company_name': 'Sphere',
#   'number_employees': '11',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-May-06',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'sphere',
#   'company_name': 'Sphere',
#   'number_employees': '11',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Apr-05',
#   'raised_amount': '500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'meevee',
#   'company_name': 'MeeVee',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Burlingame',
#   'state': 'CA',
#   'funded_date': '1-Feb-06',
#   'raised_amount': '6500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'meevee',
#   'company_name': 'MeeVee',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Burlingame',
#   'state': 'CA',
#   'funded_date': '1-Aug-06',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'meevee',
#   'company_name': 'MeeVee',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Burlingame',
#   'state': 'CA',
#   'funded_date': '1-Feb-05',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'meevee',
#   'company_name': 'MeeVee',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Burlingame',
#   'state': 'CA',
#   'funded_date': '1-Sep-07',
#   'raised_amount': '3500000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'mashery',
#   'company_name': 'Mashery',
#   'number_employees': '0',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '26-Jun-08',
#   'raised_amount': '2000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'yelp',
#   'company_name': 'Yelp',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'yelp',
#   'company_name': 'Yelp',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Oct-05',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'yelp',
#   'company_name': 'Yelp',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jul-04',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'yelp',
#   'company_name': 'Yelp',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '26-Feb-08',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'spotplex',
#   'company_name': 'Spotplex',
#   'number_employees': '3',
#   'category': 'web',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '450000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'coghead',
#   'company_name': 'Coghead',
#   'number_employees': '21',
#   'category': 'web',
#   'city': 'Redwood City',
#   'state': 'CA',
#   'funded_date': '1-Mar-06',
#   'raised_amount': '3200000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'coghead',
#   'company_name': 'Coghead',
#   'number_employees': '21',
#   'category': 'web',
#   'city': 'Redwood City',
#   'state': 'CA',
#   'funded_date': '1-Mar-07',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'zooomr',
#   'company_name': 'Zooomr',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Feb-06',
#   'raised_amount': '50000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'sidestep',
#   'company_name': 'SideStep',
#   'number_employees': '75',
#   'category': 'web',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'funded_date': '1-Feb-07',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'sidestep',
#   'company_name': 'SideStep',
#   'number_employees': '75',
#   'category': 'web',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'funded_date': '1-Jan-04',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'sidestep',
#   'company_name': 'SideStep',
#   'number_employees': '75',
#   'category': 'web',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'funded_date': '1-Dec-99',
#   'raised_amount': '2200000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'sidestep',
#   'company_name': 'SideStep',
#   'number_employees': '75',
#   'category': 'web',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'funded_date': '1-Oct-00',
#   'raised_amount': '6800000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'rockyou',
#   'company_name': 'RockYou',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'rockyou',
#   'company_name': 'RockYou',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '1-Mar-07',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'rockyou',
#   'company_name': 'RockYou',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '9-Jun-08',
#   'raised_amount': '35000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'rockyou',
#   'company_name': 'RockYou',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '27-May-08',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'unattributed'},
#  {'permalink': 'pageflakes',
#   'company_name': 'Pageflakes',
#   'number_employees': '20',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-May-06',
#   'raised_amount': '1300000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'swivel',
#   'company_name': 'Swivel',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Sep-06',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'swivel',
#   'company_name': 'Swivel',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Apr-07',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'slide',
#   'company_name': 'Slide',
#   'number_employees': '64',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jul-05',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'slide',
#   'company_name': 'Slide',
#   'number_employees': '64',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '50000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'bebo',
#   'company_name': 'Bebo',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-May-06',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'freebase',
#   'company_name': 'freebase',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Mar-06',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'freebase',
#   'company_name': 'freebase',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '42500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'metawebtechnologies',
#   'company_name': 'Metaweb Technologies',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '15-Jan-08',
#   'raised_amount': '42000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'glammedia',
#   'company_name': 'Glam Media',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Brisbane',
#   'state': 'CA',
#   'funded_date': '1-Jul-04',
#   'raised_amount': '1100000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'glammedia',
#   'company_name': 'Glam Media',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Brisbane',
#   'state': 'CA',
#   'funded_date': '1-Jul-05',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'glammedia',
#   'company_name': 'Glam Media',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Brisbane',
#   'state': 'CA',
#   'funded_date': '1-Dec-06',
#   'raised_amount': '18500000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'glammedia',
#   'company_name': 'Glam Media',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Brisbane',
#   'state': 'CA',
#   'funded_date': '1-Feb-08',
#   'raised_amount': '65000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'glammedia',
#   'company_name': 'Glam Media',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Brisbane',
#   'state': 'CA',
#   'funded_date': '1-Feb-08',
#   'raised_amount': '20000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'thefind',
#   'company_name': 'TheFind',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Feb-05',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'thefind',
#   'company_name': 'TheFind',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '4000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'thefind',
#   'company_name': 'TheFind',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'zazzle',
#   'company_name': 'Zazzle',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Redwood City',
#   'state': 'CA',
#   'funded_date': '1-Jul-05',
#   'raised_amount': '16000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'zazzle',
#   'company_name': 'Zazzle',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Redwood City',
#   'state': 'CA',
#   'funded_date': '1-Oct-07',
#   'raised_amount': '30000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'dogster',
#   'company_name': 'Dogster',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Sep-06',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'pandora',
#   'company_name': 'Pandora',
#   'number_employees': '80',
#   'category': 'web',
#   'city': 'Oakland',
#   'state': 'CA',
#   'funded_date': '1-Jan-04',
#   'raised_amount': '7800000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'pandora',
#   'company_name': 'Pandora',
#   'number_employees': '80',
#   'category': 'web',
#   'city': 'Oakland',
#   'state': 'CA',
#   'funded_date': '1-Oct-05',
#   'raised_amount': '12000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'pandora',
#   'company_name': 'Pandora',
#   'number_employees': '80',
#   'category': 'web',
#   'city': 'Oakland',
#   'state': 'CA',
#   'funded_date': '2-Mar-00',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'cafepress',
#   'company_name': 'Cafepress',
#   'number_employees': '300',
#   'category': 'web',
#   'city': 'Foster City',
#   'state': 'CA',
#   'funded_date': '1-Mar-00',
#   'raised_amount': '1200000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'cafepress',
#   'company_name': 'Cafepress',
#   'number_employees': '300',
#   'category': 'web',
#   'city': 'Foster City',
#   'state': 'CA',
#   'funded_date': '1-May-01',
#   'raised_amount': '300000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'cafepress',
#   'company_name': 'Cafepress',
#   'number_employees': '300',
#   'category': 'web',
#   'city': 'Foster City',
#   'state': 'CA',
#   'funded_date': '1-Feb-05',
#   'raised_amount': '14000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'pbwiki',
#   'company_name': 'pbwiki',
#   'number_employees': '15',
#   'category': 'web',
#   'city': '',
#   'state': 'CA',
#   'funded_date': '11-Sep-06',
#   'raised_amount': '350000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'pbwiki',
#   'company_name': 'pbwiki',
#   'number_employees': '15',
#   'category': 'web',
#   'city': '',
#   'state': 'CA',
#   'funded_date': '1-Feb-07',
#   'raised_amount': '2100000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'adbrite',
#   'company_name': 'AdBrite',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Sep-04',
#   'raised_amount': '4000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'adbrite',
#   'company_name': 'AdBrite',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Feb-06',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'adbrite',
#   'company_name': 'AdBrite',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Nov-07',
#   'raised_amount': '23000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'loomia',
#   'company_name': 'Loomia',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-05',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'loomia',
#   'company_name': 'Loomia',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Apr-08',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'meebo',
#   'company_name': 'Meebo',
#   'number_employees': '40',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Dec-05',
#   'raised_amount': '3500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'meebo',
#   'company_name': 'Meebo',
#   'number_employees': '40',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '9000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'meebo',
#   'company_name': 'Meebo',
#   'number_employees': '40',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '30-Apr-08',
#   'raised_amount': '25000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'eventbrite',
#   'company_name': 'Eventbrite',
#   'number_employees': '13',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Nov-06',
#   'raised_amount': '100000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'linkedin',
#   'company_name': 'LinkedIn',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Nov-03',
#   'raised_amount': '4700000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'linkedin',
#   'company_name': 'LinkedIn',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Oct-04',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'linkedin',
#   'company_name': 'LinkedIn',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '12800000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'linkedin',
#   'company_name': 'LinkedIn',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '17-Jun-08',
#   'raised_amount': '53000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'flickim',
#   'company_name': 'FlickIM',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Berkeley',
#   'state': 'CA',
#   'funded_date': '1-Mar-07',
#   'raised_amount': '1600000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'terabitz',
#   'company_name': 'Terabitz',
#   'number_employees': '12',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Feb-07',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'healthline',
#   'company_name': 'Healthline',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jan-06',
#   'raised_amount': '14000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'healthline',
#   'company_name': 'Healthline',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '21000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'box-net',
#   'company_name': 'Box.net',
#   'number_employees': '19',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'box-net',
#   'company_name': 'Box.net',
#   'number_employees': '19',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '23-Jan-08',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'conduit',
#   'company_name': 'Conduit',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Redwood Shores',
#   'state': 'CA',
#   'funded_date': '1-Jul-06',
#   'raised_amount': '1800000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'conduit',
#   'company_name': 'Conduit',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Redwood Shores',
#   'state': 'CA',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'edgeio',
#   'company_name': 'Edgeio',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'spotrunner',
#   'company_name': 'Spot Runner',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'funded_date': '1-Jan-06',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'spotrunner',
#   'company_name': 'Spot Runner',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '40000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'spotrunner',
#   'company_name': 'Spot Runner',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'funded_date': '7-May-08',
#   'raised_amount': '51000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'kaboodle',
#   'company_name': 'Kaboodle',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'funded_date': '1-Mar-05',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'kaboodle',
#   'company_name': 'Kaboodle',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'funded_date': '1-Mar-06',
#   'raised_amount': '2000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'kaboodle',
#   'company_name': 'Kaboodle',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'funded_date': '1-Mar-07',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'giga-omni-media',
#   'company_name': 'Giga Omni Media',
#   'number_employees': '18',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Jun-06',
#   'raised_amount': '325000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'visiblepath',
#   'company_name': 'Visible Path',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Foster City',
#   'state': 'CA',
#   'funded_date': '1-Mar-06',
#   'raised_amount': '17000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'visiblepath',
#   'company_name': 'Visible Path',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Foster City',
#   'state': 'CA',
#   'funded_date': '1-Mar-06',
#   'raised_amount': '7700000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'wink',
#   'company_name': 'Wink',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Jan-05',
#   'raised_amount': '6200000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'seesmic',
#   'company_name': 'seesmic',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '1-Nov-07',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'seesmic',
#   'company_name': 'seesmic',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'funded_date': '20-Jun-08',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'zvents',
#   'company_name': 'Zvents',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '7-Nov-06',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'zvents',
#   'company_name': 'Zvents',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '5-Oct-05',
#   'raised_amount': '200000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'eventful',
#   'company_name': 'Eventful',
#   'number_employees': '35',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '1-Sep-06',
#   'raised_amount': '7500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'eventful',
#   'company_name': 'Eventful',
#   'number_employees': '35',
#   'category': 'web',
#   'city': 'San Diego',
#   'state': 'CA',
#   'funded_date': '1-Mar-05',
#   'raised_amount': '2100000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'oodle',
#   'company_name': 'Oodle',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '1-May-06',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'oodle',
#   'company_name': 'Oodle',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'San Mateo',
#   'state': 'CA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '11000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'odesk',
#   'company_name': 'oDesk',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'odesk',
#   'company_name': 'oDesk',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-Sep-06',
#   'raised_amount': '8000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'odesk',
#   'company_name': 'oDesk',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Menlo Park',
#   'state': 'CA',
#   'funded_date': '1-Jun-08',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'simplyhired',
#   'company_name': 'SimplyHired',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '1-Mar-06',
#   'raised_amount': '13500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'simplyhired',
#   'company_name': 'SimplyHired',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mountain View',
#   'state': 'CA',
#   'funded_date': '5-Aug-05',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'ooma',
#   'company_name': 'ooma',
#   'number_employees': '47',
#   'category': 'web',
#   'city': 'Palo Alto',
# ...
#   'company_name': 'Searchles',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Washington',
#   'state': 'DC',
#   'funded_date': '1-Jul-08',
#   'raised_amount': '2000000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'payperpost',
#   'company_name': 'PayPerPost',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Orlando',
#   'state': 'FL',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'payperpost',
#   'company_name': 'PayPerPost',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Orlando',
#   'state': 'FL',
#   'funded_date': '1-Oct-06',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'affinityinternet',
#   'company_name': 'Affinity Internet',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Fort Lauderdale',
#   'state': 'FL',
#   'funded_date': '1-Oct-99',
#   'raised_amount': '60000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'affinityinternet',
#   'company_name': 'Affinity Internet',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Fort Lauderdale',
#   'state': 'FL',
#   'funded_date': '1-Jan-02',
#   'raised_amount': '25000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'multiply',
#   'company_name': 'Multiply',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Boca Raton',
#   'state': 'FL',
#   'funded_date': '1-Nov-05',
#   'raised_amount': '2000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'multiply',
#   'company_name': 'Multiply',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Boca Raton',
#   'state': 'FL',
#   'funded_date': '1-Jul-06',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'multiply',
#   'company_name': 'Multiply',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Boca Raton',
#   'state': 'FL',
#   'funded_date': '1-Aug-07',
#   'raised_amount': '16600000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'revolutionmoney',
#   'company_name': 'Revolution Money',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Largo',
#   'state': 'FL',
#   'funded_date': '1-Sep-07',
#   'raised_amount': '50000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'batanga',
#   'company_name': 'Batanga',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Miami',
#   'state': 'FL',
#   'funded_date': '1-Aug-07',
#   'raised_amount': '30000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'batanga',
#   'company_name': 'Batanga',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Miami',
#   'state': 'FL',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'divorce360',
#   'company_name': 'divorce360',
#   'number_employees': '6',
#   'category': 'web',
#   'city': 'North Palm Beach',
#   'state': 'FL',
#   'funded_date': '1-Sep-07',
#   'raised_amount': '2500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'infinitybox',
#   'company_name': 'Infinity Box',
#   'number_employees': '3',
#   'category': 'web',
#   'city': 'Tampa',
#   'state': 'FL',
#   'funded_date': '1-Jan-06',
#   'raised_amount': '18000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'infinitybox',
#   'company_name': 'Infinity Box',
#   'number_employees': '3',
#   'category': 'web',
#   'city': 'Tampa',
#   'state': 'FL',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '100000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'moli',
#   'company_name': 'MOLI',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'West Palm Beach',
#   'state': 'FL',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '29600000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'global-roaming',
#   'company_name': 'Global Roaming',
#   'number_employees': '29',
#   'category': 'mobile',
#   'city': 'Miami',
#   'state': 'FL',
#   'funded_date': '1-Feb-07',
#   'raised_amount': '7500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'global-roaming',
#   'company_name': 'Global Roaming',
#   'number_employees': '29',
#   'category': 'mobile',
#   'city': 'Miami',
#   'state': 'FL',
#   'funded_date': '1-Feb-08',
#   'raised_amount': '23000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'slingpage',
#   'company_name': 'Slingpage',
#   'number_employees': '8',
#   'category': 'software',
#   'city': 'Estero',
#   'state': 'FL',
#   'funded_date': '1-Dec-07',
#   'raised_amount': '2250000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'wrapmail',
#   'company_name': 'WrapMail',
#   'number_employees': '10',
#   'category': 'web',
#   'city': 'Fort Lauderdale',
#   'state': 'FL',
#   'funded_date': '6-Jan-07',
#   'raised_amount': '1100000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'ejamming',
#   'company_name': 'eJamming',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Boca Raton',
#   'state': 'FL',
#   'funded_date': '2-Jun-08',
#   'raised_amount': '150000',
#   'raised_currency': 'USD',
#   'round': 'unattributed'},
#  {'permalink': 'lehigh-technologies',
#   'company_name': 'Lehigh Technologies',
#   'number_employees': '',
#   'category': 'cleantech',
#   'city': 'Naples',
#   'state': 'FL',
#   'funded_date': '23-Jun-08',
#   'raised_amount': '34500000',
#   'raised_currency': 'USD',
#   'round': 'unattributed'},
#  {'permalink': 'tournease',
#   'company_name': 'TournEase',
#   'number_employees': '10',
#   'category': 'web',
#   'city': 'Lakeland',
#   'state': 'FL',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'tournease',
#   'company_name': 'TournEase',
#   'number_employees': '10',
#   'category': 'web',
#   'city': 'Lakeland',
#   'state': 'FL',
#   'funded_date': '1-Mar-08',
#   'raised_amount': '500000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'vitrue',
#   'company_name': 'Vitrue',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'funded_date': '1-Oct-07',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'vitrue',
#   'company_name': 'Vitrue',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'funded_date': '1-May-06',
#   'raised_amount': '2200000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'screamingsports',
#   'company_name': 'Screaming Sports',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '1250000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'berecruited',
#   'company_name': 'beRecruited',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'funded_date': '1-Nov-07',
#   'raised_amount': '1200000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'mfg',
#   'company_name': 'MFG',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'funded_date': '1-Sep-05',
#   'raised_amount': '14000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'mfg',
#   'company_name': 'MFG',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '4000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'mfg',
#   'company_name': 'MFG',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '26000000',
#   'raised_currency': 'USD',
#   'round': 'd'},
#  {'permalink': 'scintella-solutions',
#   'company_name': 'Scintella Solutions',
#   'number_employees': '2',
#   'category': 'consulting',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'funded_date': '30-Apr-08',
#   'raised_amount': '10000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'scribestorm',
#   'company_name': 'ScribeStorm',
#   'number_employees': '12',
#   'category': 'web',
#   'city': 'Fairfield',
#   'state': 'IA',
#   'funded_date': '24-Apr-06',
#   'raised_amount': '225000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'balihoo',
#   'company_name': 'Balihoo',
#   'number_employees': '',
#   'category': 'mobile',
#   'city': 'Boise',
#   'state': 'ID',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'balihoo',
#   'company_name': 'Balihoo',
#   'number_employees': '',
#   'category': 'mobile',
#   'city': 'Boise',
#   'state': 'ID',
#   'funded_date': '1-Jan-08',
#   'raised_amount': '4000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'info',
#   'company_name': 'Info',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Nov-04',
#   'raised_amount': '8400000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'feedburner',
#   'company_name': 'FeedBurner',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Jun-04',
#   'raised_amount': '1000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'feedburner',
#   'company_name': 'FeedBurner',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Apr-05',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'viewpoints',
#   'company_name': 'Viewpoints',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Jun-07',
#   'raised_amount': '5000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'grubhub',
#   'company_name': 'GrubHub',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Nov-07',
#   'raised_amount': '1100000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'ticketsnow',
#   'company_name': 'TicketsNow',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Rolling Meadows',
#   'state': 'IL',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '34000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'the-point',
#   'company_name': 'The Point',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Nov-07',
#   'raised_amount': '2500000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'the-point',
#   'company_name': 'The Point',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Feb-08',
#   'raised_amount': '4800000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'inkling',
#   'company_name': 'Inkling',
#   'number_employees': '2',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '20000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'crowdspring',
#   'company_name': 'crowdSPRING',
#   'number_employees': '6',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '23-May-08',
#   'raised_amount': '3000000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'ifbyphone',
#   'company_name': 'Ifbyphone',
#   'number_employees': '16',
#   'category': 'web',
#   'city': 'Skokie',
#   'state': 'IL',
#   'funded_date': '1-Jul-07',
#   'raised_amount': '1500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'fave-media',
#   'company_name': 'Fave Media',
#   'number_employees': '18',
#   'category': 'web',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '17-Jan-08',
#   'raised_amount': '1600000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'accertify',
#   'company_name': 'Accertify',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Schaumburg',
#   'state': 'IL',
#   'funded_date': '3-Jun-08',
#   'raised_amount': '4000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'firefly-energy',
#   'company_name': 'Firefly Energy',
#   'number_employees': '',
#   'category': 'cleantech',
#   'city': 'Peoria',
#   'state': 'IL',
#   'funded_date': '14-Oct-04',
#   'raised_amount': '4000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'firefly-energy',
#   'company_name': 'Firefly Energy',
#   'number_employees': '',
#   'category': 'cleantech',
#   'city': 'Peoria',
#   'state': 'IL',
#   'funded_date': '10-Jun-08',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'firefly-energy',
#   'company_name': 'Firefly Energy',
#   'number_employees': '',
#   'category': 'cleantech',
#   'city': 'Peoria',
#   'state': 'IL',
#   'funded_date': '13-Nov-06',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'savo',
#   'company_name': 'SAVO',
#   'number_employees': '68',
#   'category': 'software',
#   'city': 'Chicago',
#   'state': 'IL',
#   'funded_date': '1-Sep-05',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'chacha',
#   'company_name': 'ChaCha',
#   'number_employees': '75',
#   'category': 'web',
#   'city': 'Carmel',
#   'state': 'IN',
#   'funded_date': '1-Jan-07',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'chacha',
#   'company_name': 'ChaCha',
#   'number_employees': '75',
#   'category': 'web',
#   'city': 'Carmel',
#   'state': 'IN',
#   'funded_date': '1-Nov-07',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'betterworld',
#   'company_name': 'Better World Books',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Mishawaka',
#   'state': 'IN',
#   'funded_date': '7-Apr-08',
#   'raised_amount': '4500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'compendium-blogware',
#   'company_name': 'Compendium Blogware',
#   'number_employees': '25',
#   'category': 'software',
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'funded_date': '1-May-07',
#   'raised_amount': '1100000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'compendium-blogware',
#   'company_name': 'Compendium Blogware',
#   'number_employees': '25',
#   'category': 'software',
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'funded_date': '1-May-08',
#   'raised_amount': '1600000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'instagarage',
#   'company_name': 'Instagarage',
#   'number_employees': '4',
#   'category': 'web',
#   'city': 'New Orleans',
#   'state': 'LA',
#   'funded_date': '10-May-07',
#   'raised_amount': '25000',
#   'raised_currency': 'USD',
#   'round': 'seed'},
#  {'permalink': 'iskoot',
#   'company_name': 'iSkoot',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Cambridge',
#   'state': 'MA',
#   'funded_date': '27-Feb-07',
#   'raised_amount': '7000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'iskoot',
#   'company_name': 'iSkoot',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Cambridge',
#   'state': 'MA',
#   'funded_date': '29-Nov-06',
#   'raised_amount': '6200000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'gotuitmedia',
#   'company_name': 'Gotuit Media',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Woburn',
#   'state': 'MA',
#   'funded_date': '1-Dec-04',
#   'raised_amount': '10000000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'gotuitmedia',
#   'company_name': 'Gotuit Media',
#   'number_employees': '',
#   'category': 'web',
#   'city': 'Woburn',
#   'state': 'MA',
#   'funded_date': '1-Dec-02',
#   'raised_amount': '6000000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'carbonite',
#   'company_name': 'Carbonite',
#   'number_employees': '68',
#   'category': 'web',
#   'city': 'Boston',
#   'state': 'MA',
#   'funded_date': '1-Mar-06',
#   'raised_amount': '2500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'carbonite',
#   'company_name': 'Carbonite',
#   'number_employees': '68',
#   'category': 'web',
#   'city': 'Boston',
#   'state': 'MA',
#   'funded_date': '1-Dec-06',
#   'raised_amount': '3500000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  ...]

# %%
[row for row in csv_data if row["company_name"] == "Facebook"]
# Out:
# [{'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Sep-04',
#   'raised_amount': '500000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-May-05',
#   'raised_amount': '12700000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '27500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Oct-07',
#   'raised_amount': '300000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Mar-08',
#   'raised_amount': '40000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '15-Jan-08',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-May-08',
#   'raised_amount': '100000000',
#   'raised_currency': 'USD',
#   'round': 'debt_round'}]

# %%
import csv

def filter_csv(csv_data, options):
    print(options)
    if options:
        key = list(options.keys())[0]
        fltrd = [row for row in csv_data if row[key] == options[key]]
        del(options[key])

        return filter_csv(fltrd, options) if options else fltrd

def where(options={}):
    with open("../startup_funding.csv", "rt") as csvfile:
        file_data = csv.reader(csvfile, delimiter=",", quotechar='"')
        headers = next(file_data)
        csv_data = [dict(zip(headers, i)) for i in file_data]
    
    result = filter_csv(csv_data, options) 
    return result

# %%
searchdict = {'company_name': 'Facebook'}
where(searchdict)
# Out:
# {'company_name': 'Facebook'}
# [{'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Sep-04',
#   'raised_amount': '500000',
#   'raised_currency': 'USD',
#   'round': 'angel'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-May-05',
#   'raised_amount': '12700000',
#   'raised_currency': 'USD',
#   'round': 'a'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Apr-06',
#   'raised_amount': '27500000',
#   'raised_currency': 'USD',
#   'round': 'b'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Oct-07',
#   'raised_amount': '300000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-Mar-08',
#   'raised_amount': '40000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '15-Jan-08',
#   'raised_amount': '15000000',
#   'raised_currency': 'USD',
#   'round': 'c'},
#  {'permalink': 'facebook',
#   'company_name': 'Facebook',
#   'number_employees': '450',
#   'category': 'web',
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'funded_date': '1-May-08',
#   'raised_amount': '100000000',
#   'raised_currency': 'USD',
#   'round': 'debt_round'}]
